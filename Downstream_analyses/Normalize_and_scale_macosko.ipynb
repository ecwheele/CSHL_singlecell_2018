# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
directory = "/projects/ps-yeolab3/ecwheele/teaching_test/processed_files/"

filtered_counts = pd.read_csv(directory+"counts_filt_500genes_233cells.csv", index_col=0)
print(filtered_counts.shape)
filtered_counts.head()
# Out:
# (3139, 2233)
#                CTTGTGCGGGAA  GGCCGCAGTCCG  GATTGGGAGGCA  GCGCAACTGCTC  \
# GENE
# 0610007P14Rik             1             1             2             0
# 0610009B22Rik             0             2             1             1
# 0610009D07Rik             4             6             1             6
# 0610011F06Rik             0             1             1             0
# 1110001A16Rik             4             1             0             2
#
#                AGTCAAGCCCTC  CCTCCTAGTTGG  GATTTCCTCTGA  CCTGTGACACAC  \
# GENE
# 0610007P14Rik             0             0             0             0
# 0610009B22Rik             3             1             1             0
# 0610009D07Rik             5             1             0             1
# 0610011F06Rik             2             1             0             0
# 1110001A16Rik             0             0             2             1
#
#                TGCGAGAGCTTG  TGTCCATGCGTA      ...       GGGCGAGTGATG  \
# ...

# %%
tpm = (filtered_counts / filtered_counts.sum())*10000
print(tpm.shape)
tpm.head()
# Out:
# (3139, 2233)
#                CTTGTGCGGGAA  GGCCGCAGTCCG  GATTGGGAGGCA  GCGCAACTGCTC  \
# GENE
# 0610007P14Rik      0.628931      0.616675      2.209945      0.000000
# 0610009B22Rik      0.000000      1.233350      1.104972      0.847745
# 0610009D07Rik      2.515723      3.700049      1.104972      5.086470
# 0610011F06Rik      0.000000      0.616675      1.104972      0.000000
# 1110001A16Rik      2.515723      0.616675      0.000000      1.695490
#
#                AGTCAAGCCCTC  CCTCCTAGTTGG  GATTTCCTCTGA  CCTGTGACACAC  \
# GENE
# 0610007P14Rik      0.000000      0.000000      0.000000      0.000000
# 0610009B22Rik      3.088962      1.123217      1.391982      0.000000
# 0610009D07Rik      5.148270      1.123217      0.000000      1.420455
# 0610011F06Rik      2.059308      1.123217      0.000000      0.000000
# 1110001A16Rik      0.000000      0.000000      2.783964      1.420455
#
#                TGCGAGAGCTTG  TGTCCATGCGTA      ...       GGGCGAGTGATG  \
# ...
